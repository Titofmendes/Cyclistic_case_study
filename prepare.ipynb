# %%
import pandas as pd

# List of months used in the analysis
months = [
    202505,
    202506,
    202507,
    202508,
    202509,
    202510,
    202511,
    202512,
    202601,
    202602,
    202603,
    202604
]

# %%
# function to load a specific dataset
def load_csv(month):
    return pd.read_csv(f"../raw_data/{month}-divvy-tripdata/{month}-divvy-tripdata.csv")

# %%
# function to return the number of rows of a dataset
def calculate_no_rows(df):
    return len(df)

# %%
# function to return the columns of a dataset
def get_columns(df):
    return df.columns

# %%
# function to assess if all datasets have the same columns
def check_columns(months):
    # Define the reference for the columns based on the first dataset
    columns = get_columns(load_csv(months[0]))
    # Iterate over the remaining datasets and get the columns
    for month in months[1:]:
        df_columns_list = get_columns(load_csv(month))
        # Compare the columns of the dataset with the reference
        for x in range(len(df_columns_list)):
            if df_columns_list[x] != columns[x]:
                break
                return f"Columns in {month} are different from the reference"
    return f"All datasets have the same columns"

# %%
# function to check if the 'ride_id' column has null values
def check_ride_id(df):
    if len(df) == df['ride_id'].count():
        return "No null values for 'ride_id'."
    return "'ride_id' presents null values!"

# %%
# function to check if there are duplicates in 'ride_id'
def check_unique_ride_id(df):
    if len(df) == len(df['ride_id'].unique()):
        return "No duplicates."
    return "There are duplicates!"

# %%
# function to check if the 'member_casual' column has null values
def check_member_casual(df):
    if len(df) == df['member_casual'].count():
        return "No null values for 'member_casual'."
    return "'member_casual' presents null values!"

# %%
# function to check if the 'started_at' column has null values
def check_started_at(df):
    if len(df) == df['started_at'].count():
        return "No null values for 'started_at'."
    return "'started_at' presents null values!"

# %%
# function to check if the 'ended_at' column has null values
def check_ended_at(df):
    if len(df) == df['ended_at'].count():
        return "No null values for 'ended_at'."
    return "'ended_at' presents null values!"

# %%
# function to calculate the number of rows with null values
def calculate_null_values(month):
    df = load_csv(month)
    return f"Total rows: {len(df)} | Rows without null: {len(df.dropna())} | Rows with null: {len(df) - len(df.dropna())} | % null: {((len(df) - len(df.dropna()))/len(df))*100:.2f}"

# %%
# function to remove rows with null values from the dataset
def remove_nulls(month):
    df = load_csv(month)
    return df.dropna()

# %%
# Print the column names
print(load_csv(months[0]).info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 502456 entries, 0 to 502455
# Data columns (total 13 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ride_id             502456 non-null  str
#  1   rideable_type       502456 non-null  str
#  2   started_at          502456 non-null  str
#  3   ended_at            502456 non-null  str
#  4   start_station_name  399096 non-null  str
#  5   start_station_id    399096 non-null  str
#  6   end_station_name    395020 non-null  str
#  7   end_station_id      395020 non-null  str
#  8   start_lat           502456 non-null  float64
#  9   start_lng           502456 non-null  float64
#  10  end_lat             501905 non-null  float64
#  11  end_lng             501905 non-null  float64
#  12  member_casual       502456 non-null  str
# dtypes: float64(4), str(9)
# memory usage: 49.8 MB
# None

# %%
# Print the number of rows for each data file
for month in months:
    print(f"Data file '{month}' -> {calculate_no_rows(load_csv(month))} rows.")
# Out:
# Data file '202505' -> 502456 rows.
# Data file '202506' -> 678904 rows.
# Data file '202507' -> 763432 rows.
# Data file '202508' -> 790177 rows.
# Data file '202509' -> 714759 rows.
# Data file '202510' -> 646039 rows.
# Data file '202511' -> 356628 rows.
# Data file '202512' -> 140534 rows.
# Data file '202601' -> 137787 rows.
# Data file '202602' -> 201450 rows.
# Data file '202603' -> 317037 rows.
# Data file '202604' -> 448252 rows.

# %%
# Check if all datasets have the same columns
print(check_columns(months))
# Out:
# All datasets have the same columns

# %%
# Check if there are null values in the 'ride_id' column for all datasets
for month in months:
    print(f"Month: {month}")
    print(check_ride_id(load_csv(month)))
    print("----------------")
# Out:
# Month: 202505
# No null values for 'ride_id'.
# ----------------
# Month: 202506
# No null values for 'ride_id'.
# ----------------
# Month: 202507
# No null values for 'ride_id'.
# ----------------
# Month: 202508
# No null values for 'ride_id'.
# ----------------
# Month: 202509
# No null values for 'ride_id'.
# ----------------
# Month: 202510
# No null values for 'ride_id'.
# ----------------
# Month: 202511
# No null values for 'ride_id'.
# ----------------
# Month: 202512
# No null values for 'ride_id'.
# ----------------
# Month: 202601
# No null values for 'ride_id'.
# ----------------
# Month: 202602
# No null values for 'ride_id'.
# ----------------
# Month: 202603
# No null values for 'ride_id'.
# ----------------
# Month: 202604
# No null values for 'ride_id'.
# ----------------

# %%
# Check if there are null values in the 'member_casual' column for all datasets
for month in months:
    print(f"Month: {month}")
    print(check_member_casual(load_csv(month)))
    print("----------------")
# Out:
# Month: 202505
# No null values for 'member_casual'.
# ----------------
# Month: 202506
# No null values for 'member_casual'.
# ----------------
# Month: 202507
# No null values for 'member_casual'.
# ----------------
# Month: 202508
# No null values for 'member_casual'.
# ----------------
# Month: 202509
# No null values for 'member_casual'.
# ----------------
# Month: 202510
# No null values for 'member_casual'.
# ----------------
# Month: 202511
# No null values for 'member_casual'.
# ----------------
# Month: 202512
# No null values for 'member_casual'.
# ----------------
# Month: 202601
# No null values for 'member_casual'.
# ----------------
# Month: 202602
# No null values for 'member_casual'.
# ----------------
# Month: 202603
# No null values for 'member_casual'.
# ----------------
# Month: 202604
# No null values for 'member_casual'.
# ----------------

# %%
# Check if there are duplicate values in the 'ride_id' column for all datasets
for month in months:
    print(f"Month: {month}")
    print(check_unique_ride_id(load_csv(month)))
    print("----------------")
# Out:
# Month: 202505
# No duplicates.
# ----------------
# Month: 202506
# No duplicates.
# ----------------
# Month: 202507
# No duplicates.
# ----------------
# Month: 202508
# No duplicates.
# ----------------
# Month: 202509
# No duplicates.
# ----------------
# Month: 202510
# No duplicates.
# ----------------
# Month: 202511
# No duplicates.
# ----------------
# Month: 202512
# No duplicates.
# ----------------
# Month: 202601
# No duplicates.
# ----------------
# Month: 202602
# No duplicates.
# ----------------
# Month: 202603
# No duplicates.
# ----------------
# Month: 202604
# No duplicates.
# ----------------

# %%
# Check unique values for the 'member_casual' column
for month in months:
    print(f"Month: {month}")
    print(load_csv(month)['member_casual'].unique())
    print("------------------")
# Out:
# Month: 202505
# <StringArray>
# ['member', 'casual']
# Length: 2, dtype: str
# ------------------
# Month: 202506
# <StringArray>
# ['member', 'casual']
# Length: 2, dtype: str
# ------------------
# Month: 202507
# <StringArray>
# ['member', 'casual']
# Length: 2, dtype: str
# ------------------
# Month: 202508
# <StringArray>
# ['casual', 'member']
# Length: 2, dtype: str
# ------------------
# Month: 202509
# <StringArray>
# ['member', 'casual']
# Length: 2, dtype: str
# ------------------
# Month: 202510
# <StringArray>
# ['member', 'casual']
# Length: 2, dtype: str
# ------------------
# Month: 202511
# <StringArray>
# ['casual', 'member']
# Length: 2, dtype: str
# ------------------
# Month: 202512
# <StringArray>
# ['member', 'casual']
# Length: 2, dtype: str
# ------------------
# Month: 202601
# <StringArray>
# ['member', 'casual']
# Length: 2, dtype: str
# ------------------
# Month: 202602
# <StringArray>
# ['member', 'casual']
# Length: 2, dtype: str
# ------------------
# Month: 202603
# <StringArray>
# ['member', 'casual']
# Length: 2, dtype: str
# ------------------
# Month: 202604
# <StringArray>
# ['member', 'casual']
# Length: 2, dtype: str
# ------------------

# %%
# Check if there are null values in the 'started_at' column
for month in months:
    print(f"Month: {month}")
    print(check_started_at(load_csv(month)))
    print("----------------")
# Out:
# Month: 202505
# No null values for 'started_at'.
# ----------------
# Month: 202506
# No null values for 'started_at'.
# ----------------
# Month: 202507
# No null values for 'started_at'.
# ----------------
# Month: 202508
# No null values for 'started_at'.
# ----------------
# Month: 202509
# No null values for 'started_at'.
# ----------------
# Month: 202510
# No null values for 'started_at'.
# ----------------
# Month: 202511
# No null values for 'started_at'.
# ----------------
# Month: 202512
# No null values for 'started_at'.
# ----------------
# Month: 202601
# No null values for 'started_at'.
# ----------------
# Month: 202602
# No null values for 'started_at'.
# ----------------
# Month: 202603
# No null values for 'started_at'.
# ----------------
# Month: 202604
# No null values for 'started_at'.
# ----------------

# %%
# Check if there are null values in the 'ended_at' column
for month in months:
    print(f"Month: {month}")
    print(check_ended_at(load_csv(month)))
    print("----------------")
# Out:
# Month: 202505
# No null values for 'ended_at'.
# ----------------
# Month: 202506
# No null values for 'ended_at'.
# ----------------
# Month: 202507
# No null values for 'ended_at'.
# ----------------
# Month: 202508
# No null values for 'ended_at'.
# ----------------
# Month: 202509
# No null values for 'ended_at'.
# ----------------
# Month: 202510
# No null values for 'ended_at'.
# ----------------
# Month: 202511
# No null values for 'ended_at'.
# ----------------
# Month: 202512
# No null values for 'ended_at'.
# ----------------
# Month: 202601
# No null values for 'ended_at'.
# ----------------
# Month: 202602
# No null values for 'ended_at'.
# ----------------
# Month: 202603
# No null values for 'ended_at'.
# ----------------
# Month: 202604
# No null values for 'ended_at'.
# ----------------

# %%
# Check number of rows with null values for all datasets
for month in months:
    print(f"Month: {month}")
    print(calculate_null_values(month))
    print("-------------------------")
# Out:
# Month: 202505
# Total rows: 502456 | Rows without null: 340634 | Rows with null: 161822 | % null: 32.21
# -------------------------
# Month: 202506
# Total rows: 678904 | Rows without null: 446363 | Rows with null: 232541 | % null: 34.25
# -------------------------
# Month: 202507
# Total rows: 763432 | Rows without null: 494293 | Rows with null: 269139 | % null: 35.25
# -------------------------
# Month: 202508
# Total rows: 790177 | Rows without null: 515533 | Rows with null: 274644 | % null: 34.76
# -------------------------
# Month: 202509
# Total rows: 714759 | Rows without null: 467881 | Rows with null: 246878 | % null: 34.54
# -------------------------
# Month: 202510
# Total rows: 646039 | Rows without null: 417877 | Rows with null: 228162 | % null: 35.32
# -------------------------
# Month: 202511
# Total rows: 356628 | Rows without null: 235010 | Rows with null: 121618 | % null: 34.10
# -------------------------
# Month: 202512
# Total rows: 140534 | Rows without null: 96158 | Rows with null: 44376 | % null: 31.58
# -------------------------
# Month: 202601
# Total rows: 137787 | Rows without null: 97118 | Rows with null: 40669 | % null: 29.52
# -------------------------
# Month: 202602
# Total rows: 201450 | Rows without null: 147622 | Rows with null: 53828 | % null: 26.72
# -------------------------
# Month: 202603
# Total rows: 317037 | Rows without null: 221900 | Rows with null: 95137 | % null: 30.01
# -------------------------
# Month: 202604
# Total rows: 448252 | Rows without null: 302413 | Rows with null: 145839 | % null: 32.54
# -------------------------

# %%
# Removal of rows with null values for all datasets
for month in months:
    df = remove_nulls(month)
    df.to_csv(f"../cleaned_data/20260510-no_nulls/{month}_no_nulls.csv", index=False)
    print(f"{month} .csv file created!")
# Out:
# 202505 .csv file created!
# 202506 .csv file created!
# 202507 .csv file created!
# 202508 .csv file created!
# 202509 .csv file created!
# 202510 .csv file created!
# 202511 .csv file created!
# 202512 .csv file created!
# 202601 .csv file created!
# 202602 .csv file created!
# 202603 .csv file created!
# 202604 .csv file created!
