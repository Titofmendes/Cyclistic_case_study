# %%
import pandas as pd

# List of months used in the analysis
months = [
    202505,
    202506,
    202507,
    202508,
    202509,
    202510,
    202511,
    202512,
    202601,
    202602,
    202603,
    202604
]

# %%
# function to load a specific dataset
def load_csv(month):
    return pd.read_csv(f"../cleaned_data/20260510-no_nulls/{month}_no_nulls.csv")

# %%
# function to convert the 'started_at' and 'ended_at' columns into datetime
def convert_to_datetime(df):
    df['started_at'] = pd.to_datetime(df['started_at'])
    df['ended_at'] = pd.to_datetime(df['ended_at'])
    return df

# %%
# function to calculate the weekday
def calculate_weekday(df):
    df['weekday'] = df['started_at'].dt.day_name()
    return df

# %%
# function to calculate the ride duration
def calculate_ride_duration(month):
    df = load_csv(month)
    df = convert_to_datetime(df)
    df['ride_duration'] = df['ended_at'] - df['started_at']
    df = calculate_weekday(df)
    return df

# %%
# function to check if ride duration has negative values
def check_ride_duration(month):
    df = calculate_ride_duration(month)
    mask = df['ride_duration'] <= pd.Timedelta(0)
    if len(df[mask]) > 0:
        return f"There are {len(df[mask])} rows with zero or negative values."
    return "There are no zero or negative values."

# %%
# function to remove the rows with zero or negative values for the 'ride_duration' column
def remove_negative_ride_durations(month):
    df = calculate_ride_duration(month)
    mask = df['ride_duration'] > pd.Timedelta(0)
    return df[mask]

# %%
# function to load cleaned datasets
def load_clean_csv(month):
    return pd.read_csv(f"../cleaned_data/20260510-no_negative_ride_durations/{month}_no_negative_ride_durations.csv")

# %%
# function to check if there are incorrectly registered datetimes
def check_datetime(month, start=True):
    df = load_clean_csv(month)
    df = convert_to_datetime(df)
    year = int(str(month)[:4])
    mon = int(str(month)[-2:])
    if start:
        mask_start = (df['started_at'].dt.year == year) & (df['started_at'].dt.month == mon)
        df = df[~mask_start]
        mask_end = (df['ended_at'].dt.year == year) & (df['ended_at'].dt.month == mon)
        return df[~mask_end]
    else:
        mask = (df['ended_at'].dt.year == year) & (df['ended_at'].dt.month == mon)
        return df[~mask]

# %%
# Check if there are zero or negative values for the 'ride_duration' column for all datasets
for month in months:
    print(f"Month: {month}")
    print(check_ride_duration(month))
    print("----------------------------------------")
# Out:
# Month: 202505
# There are no zero or negative values.
# ----------------------------------------
# Month: 202506
# There are no zero or negative values.
# ----------------------------------------
# Month: 202507
# There are no zero or negative values.
# ----------------------------------------
# Month: 202508
# There are no zero or negative values.
# ----------------------------------------
# Month: 202509
# There are no zero or negative values.
# ----------------------------------------
# Month: 202510
# There are no zero or negative values.
# ----------------------------------------
# Month: 202511
# There are 19 rows with zero or negative values.
# ----------------------------------------
# Month: 202512
# There are no zero or negative values.
# ----------------------------------------
# Month: 202601
# There are no zero or negative values.
# ----------------------------------------
# Month: 202602
# There are no zero or negative values.
# ----------------------------------------
# Month: 202603
# There are no zero or negative values.
# ----------------------------------------
# Month: 202604
# There are no zero or negative values.
# ----------------------------------------

# %%
# Create new data files with converted datetimes and added 'ride_duration' and 'weekday' columns
for month in months:
    df = calculate_ride_duration(month)
    df.to_csv(f"../cleaned_data/20260510-ride_durations/{month}_ride_durations.csv", index=False)
    print(f"{month} csv file created!")
# Out:
# 202505 csv file created!
# 202506 csv file created!
# 202507 csv file created!
# 202508 csv file created!
# 202509 csv file created!
# 202510 csv file created!
# 202511 csv file created!
# 202512 csv file created!
# 202601 csv file created!
# 202602 csv file created!
# 202603 csv file created!
# 202604 csv file created!

# %%
# Create new data files with converted datetimes, 'ride_duration' and 'weekday' columns, and removed rows with zero or negative ride durations
for month in months:
    df = remove_negative_ride_durations(month)
    df.to_csv(f"../cleaned_data/20260510-no_negative_ride_durations/{month}_no_negative_ride_durations.csv", index=False)
    print(f"{month} csv file created!")
# Out:
# 202505 csv file created!
# 202506 csv file created!
# 202507 csv file created!
# 202508 csv file created!
# 202509 csv file created!
# 202510 csv file created!
# 202511 csv file created!
# 202512 csv file created!
# 202601 csv file created!
# 202602 csv file created!
# 202603 csv file created!
# 202604 csv file created!

# %%
# Check for incorrectly defined datetime values for the 'started_at' column
for month in months:
    print(f"Month: {month}")
    print(len(check_datetime(month, start=True)))
    print("----------------------------------------")
# Out:
# Month: 202505
# 0
# ----------------------------------------
# Month: 202506
# 0
# ----------------------------------------
# Month: 202507
# 0
# ----------------------------------------
# Month: 202508
# 0
# ----------------------------------------
# Month: 202509
# 0
# ----------------------------------------
# Month: 202510
# 0
# ----------------------------------------
# Month: 202511
# 0
# ----------------------------------------
# Month: 202512
# 0
# ----------------------------------------
# Month: 202601
# 0
# ----------------------------------------
# Month: 202602
# 0
# ----------------------------------------
# Month: 202603
# 0
# ----------------------------------------
# Month: 202604
# 0
# ----------------------------------------

# %%
# Check for incorrectly defined datetime values for the 'ended_at' column
for month in months:
    print(f"Month: {month}")
    print(len(check_datetime(month, start=False)))
    print("----------------------------------------")
# Out:
# Month: 202505
# 0
# ----------------------------------------
# Month: 202506
# 0
# ----------------------------------------
# Month: 202507
# 0
# ----------------------------------------
# Month: 202508
# 0
# ----------------------------------------
# Month: 202509
# 0
# ----------------------------------------
# Month: 202510
# 0
# ----------------------------------------
# Month: 202511
# 0
# ----------------------------------------
# Month: 202512
# 0
# ----------------------------------------
# Month: 202601
# 0
# ----------------------------------------
# Month: 202602
# 0
# ----------------------------------------
# Month: 202603
# 0
# ----------------------------------------
# Month: 202604
# 20
# ----------------------------------------

# %%
# Check the last dataset which presented 20 rows outside the defined time window
df = check_datetime(months[11], start=False)
df
# Out:
#                  ride_id  rideable_type              started_at  \
# 26780   D28B306F00821227   classic_bike 2026-04-30 23:57:36.236
# 36225   E923A7ACDD4A9293   classic_bike 2026-04-30 23:58:06.960
# 71534   2038F30519CBC7E5  electric_bike 2026-04-30 23:53:54.933
# 75527   5C56F4FB55D5B5F5  electric_bike 2026-04-30 23:52:06.627
# 86744   41E2750A57535CF7  electric_bike 2026-04-30 23:58:04.347
# 99294   15521787039F37E5   classic_bike 2026-04-30 23:54:44.934
# 131312  4EBCC6DF233878B6   classic_bike 2026-04-30 23:57:58.221
# 131314  EAB7C279D822C763   classic_bike 2026-04-30 23:58:36.620
# 131420  5232F2CB3D297D55   classic_bike 2026-04-30 23:57:23.904
# 137553  82EDB771CE5282E8   classic_bike 2026-04-30 00:34:54.913
# 221503         CHI02109         Wilton Ave & Diversey Pkwy       CHI02052
# 267793         CHI02021             Michigan Ave & 11th St       CHI02025
# 270222         CHI00476         Clarendon Ave & Gordon Ter       CHI00455
# 285565         CHI00516            Damen Ave & Melrose Ave       CHI00516
#
#         start_lat  start_lng    end_lat    end_lng member_casual  \
# 26780   41.978017 -87.668019  41.978017 -87.668019        member
# 36225   41.885637 -87.641823  41.883143 -87.637242        casual
# 71534   41.978017 -87.668019  42.001044 -87.661198        member
# 75527   41.891072 -87.666611  41.895745 -87.698653        casual
# 86744   41.961041 -87.705866  41.961004 -87.649603        casual
# 99294   41.869590 -87.623961  41.880958 -87.616743        member
# 131312  41.883602 -87.648627  41.881660 -87.641150        member
# 131314  41.883602 -87.648627  41.881660 -87.641150        member
# 131420  41.883602 -87.648627  41.881660 -87.641150        member
# 137553  41.830777 -87.632504  41.794301 -87.601450        casual
# 142031  41.919936 -87.648830  41.923650 -87.648940        casual
# 142135  41.919936 -87.648830  41.923650 -87.648940        member
# 153477  41.894877 -87.632326  41.949473 -87.646453        member
# 154116  41.888960 -87.649730  41.896362 -87.654061        casual
# 196503  41.883165 -87.651100  41.921822 -87.644140        member
# 197726  41.885492 -87.652289  41.940232 -87.652944        member
# 221503  41.926940 -87.641480  41.932418 -87.652705        member
# 267793  41.853214 -87.631872  41.869590 -87.623961        casual
# 270222  41.952833 -87.649993  41.957867 -87.649505        member
# 285565  41.940600 -87.678500  41.940600 -87.678500        casual
#
#                  ride_duration   weekday
# 26780   0 days 00:18:27.192000  Thursday
# 36225   0 days 00:02:27.860000  Thursday
# 71534   0 days 00:09:40.261000  Thursday
# 75527   0 days 00:09:24.696000  Thursday
# 86744   0 days 00:14:35.507000  Thursday
# 99294   0 days 00:11:00.641000  Thursday
# 131312  0 days 00:04:44.760000  Thursday
# 131314  0 days 00:04:08.781000  Thursday
# 131420  0 days 00:04:48.118000  Thursday
# 137553  1 days 00:34:49.460000  Thursday
# 142031  0 days 00:03:52.442000  Thursday
# 142135  0 days 00:03:04.255000  Thursday
# 153477  0 days 00:14:58.691000  Thursday
# 154116  0 days 00:05:27.539000  Thursday
# 196503  0 days 00:14:07.928000  Thursday
# 197726  0 days 02:38:46.087000  Thursday
# 221503  0 days 00:04:58.579000  Thursday
# 267793  0 days 20:01:49.903000  Thursday
# 270222  0 days 17:50:13.912000  Thursday
# 285565  0 days 00:09:46.965000  Thursday

# %%
# Perform the final cleaning
for month in months:
    df = load_clean_csv(month)
    if len(check_datetime(month, start=False)) > 0:
        mask = check_datetime(month, start=False)
        df.drop(mask.index).to_csv(f"../cleaned_data/20260510-final/{month}_final.csv", index=False)
    else:
        df.to_csv(f"../cleaned_data/20260510-final/{month}_final.csv", index=False)
    print(f"{month} .csv file created!")
# Out:
# 202505 .csv file created!
# 202506 .csv file created!
# 202507 .csv file created!
# 202508 .csv file created!
# 202509 .csv file created!
# 202510 .csv file created!
# 202511 .csv file created!
# 202512 .csv file created!
# 202601 .csv file created!
# 202602 .csv file created!
# 202603 .csv file created!
# 202604 .csv file created!
